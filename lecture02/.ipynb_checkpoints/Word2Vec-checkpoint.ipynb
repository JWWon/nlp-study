# %%
import pandas as pd

train = pd.read_csv('../data/imdb/labeledTrainData.tsv', header=0, delimiter='\t', quoting=3)
test = pd.read_csv('../data/imdb/testData.tsv', header=0, delimiter='\t', quoting=3)
unlabeled_train = pd.read_csv('../data/imdb/unlabeledTrainData.tsv', header=0, delimiter='\t', quoting=3)

print(train.shape)
print(test.shape)
print(unlabeled_train.shape)
# Out:
# (25000, 3)
# (25000, 2)
# (50000, 2)

# %%
train.head()
# Out:
#          id  sentiment                                             review
# 0  "5814_8"          1  "With all this stuff going down at the moment ...
# 1  "2381_9"          1  "\"The Classic War of the Worlds\" by Timothy ...
# 2  "7759_3"          0  "The film starts with a manager (Nicholas Bell...
# 3  "3630_4"          0  "It must be assumed that those who praised thi...
# 4  "9495_8"          1  "Superbly trashy and wondrously unpretentious ...

# %%
test.head()
# Out:
#            id                                             review
# 0  "12311_10"  "Naturally in a film who's main themes are of ...
# 1    "8348_2"  "This movie is a disaster within a disaster fi...
# 2    "5828_4"  "All in all, this is a movie for kids. We saw ...
# 3    "7186_2"  "Afraid of the Dark left me with the impressio...
# 4   "12128_7"  "A very accurate depiction of small time mob l...

# %%
unlabeled_train.head()
# Out:
#           id                                             review
# 0   "9999_0"  "Watching Time Chasers, it obvious that it was...
# 1  "45057_0"  "I saw this film about 20 years ago and rememb...
# 2  "15561_0"  "Minor Spoilers<br /><br />In New York, Joan B...
# 3   "7161_0"  "I went to see this film with a great deal of ...
# 4  "43971_0"  "Yes, I agree with everyone on this site this ...

# %%
# 텍스트 정제 과정을 모듈로 만듦
from KaggleWord2VecUtility import KaggleWord2VecUtility

KaggleWord2VecUtility.review_to_wordlist(train['review'][0])[:10]
# Out:
# ['with', 'all', 'this', 'stuff', 'go', 'down', 'at', 'the', 'moment', 'with']

# %%
sentences = []

for review in train['review']:
    sentences += KaggleWord2VecUtility.review_to_sentences(review, remove_stopwords=False)
    
for review in unlabeled_train['review']:
    sentences += KaggleWord2VecUtility.review_to_sentences(review, remove_stopwords=False)
# Out:
# /Users/jiwoonwon/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:219: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# /Users/jiwoonwon/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.happierabroad.com"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/jiwoonwon/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.archive.org/details/LovefromaStranger"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# ...

# %% [markdown]
# ### Word2Vec 모델 학습
# 전처리를 거쳐 파싱된 문장의 목록으로 모델을 학습시킬 준비가 됨.

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', \
                    level=logging.INFO)

# %%
# 파라미터값 지정
num_features = 300 # 문자벡터 차원 수
min_word_count = 40 # 최소 문자 수
num_workers = 4 # 병렬 처리 스레드 수
context = 10 # 문자열 창 크기
downsampling = 1e-3 # 문자 빈도수 Downsample

# 초기화 및 모델 학습
from gensim.models import word2vec

# 모델 학습
model = word2vec.Word2Vec(sentences,
                          workers=num_workers,
                          size=num_features,
                          min_count=min_word_count,
                          window=context,
                          sample=downsampling)

model
# Out:
# 2018-07-01 14:43:06,004 : INFO : 'pattern' package not found; tag filters are not available for English
# 2018-07-01 14:43:06,011 : INFO : collecting all words and their counts
# 2018-07-01 14:43:06,012 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-07-01 14:43:06,069 : INFO : PROGRESS: at sentence #10000, processed 225803 words, keeping 12465 word types
# 2018-07-01 14:43:06,128 : INFO : PROGRESS: at sentence #20000, processed 451892 words, keeping 17070 word types
# 2018-07-01 14:43:06,175 : INFO : PROGRESS: at sentence #30000, processed 671314 words, keeping 20370 word types
# 2018-07-01 14:43:06,224 : INFO : PROGRESS: at sentence #40000, processed 897814 words, keeping 23125 word types
# 2018-07-01 14:43:06,273 : INFO : PROGRESS: at sentence #50000, processed 1116962 words, keeping 25365 word types
# 2018-07-01 14:43:06,321 : INFO : PROGRESS: at sentence #60000, processed 1338403 words, keeping 27283 word types
# ...

# %%
# 학습이 완료되면 필요 없는 메모리를 unload 시킴
model.init_sims(replace=True)

model_name = '300features_40minwords_10text'
model.save(model_name)
# Out:
# 2018-07-01 14:54:59,749 : INFO : precomputing L2-norms of word weight vectors
# 2018-07-01 14:54:59,888 : INFO : saving Word2Vec object under 300features_40minwords_10text, separately None
# 2018-07-01 14:54:59,888 : INFO : not storing attribute vectors_norm
# 2018-07-01 14:54:59,889 : INFO : not storing attribute cum_table
# 2018-07-01 14:55:00,235 : INFO : saved 300features_40minwords_10text

# %% [markdown]
# ### 모델 결과 탐색

# %%
# 유사도가 없는 단어 추출
model.wv.doesnt_match('man woman child kitchen'.split())
# Out:
# 'kitchen'

# %%
model.wv.doesnt_match('france england germany berlin'.split())
# Out:
# 2018-07-01 14:55:07,021 : WARNING : vectors for words {'france', 'germany'} are not present in the model, ignoring these words
# 'england'

# %%
# 가장 유사한 단어를 추출
model.wv.most_similar('man')
# Out:
# [('woman', 0.643352746963501),
#  ('ladi', 0.506278932094574),
#  ('lad', 0.4998595416545868),
#  ('millionair', 0.4988023638725281),
#  ('loner', 0.48662811517715454),
#  ('businessman', 0.48361751437187195),
#  ('doctor', 0.4659658670425415),
#  ('men', 0.4639666676521301),
#  ('farmer', 0.46229997277259827),
#  ('boxer', 0.461588978767395)]

# %%
model.wv.most_similar('queen')
# Out:
# [('princess', 0.5977877378463745),
#  ('latifah', 0.5815005302429199),
#  ('goddess', 0.5547471046447754),
#  ('madam', 0.5483725070953369),
#  ('stepmoth', 0.5461241006851196),
#  ('regina', 0.539936900138855),
#  ('maid', 0.5333166718482971),
#  ('mistress', 0.5300787091255188),
#  ('princ', 0.52704918384552),
#  ('seductress', 0.5255980491638184)]

# %% [markdown]
# ### Word2Vec으로 벡터화한 단어를 t-SNE를 통해 시각화

# %%
from sklearn.manifold import TSNE
import matplotlib as mpl
import matplotlib.pyplot as plt
import gensim
import gensim.models as g

# 그래프에서 폰트 깨지는 문제 해결
mpl.rcParams['axes.unicode_minus'] = False

model_name = '300features_40minwords_10text'
model = g.Doc2Vec.load(model_name)

vocab = list(model.wv.vocab)
X = model[vocab]

print(len(X))
print(X[0][:10])
tsne = TSNE(n_components=2)

# 100개의 단어에 대해서만 시각화
X_tsne = tsne.fit_transform(X[:100, :])
# Out:
# 2018-07-01 14:55:13,417 : INFO : loading Doc2Vec object from 300features_40minwords_10text
# 2018-07-01 14:55:13,652 : INFO : loading wv recursively from 300features_40minwords_10text.wv.* with mmap=None
# 2018-07-01 14:55:13,653 : INFO : setting ignored attribute vectors_norm to None
# 2018-07-01 14:55:13,654 : INFO : loading vocabulary recursively from 300features_40minwords_10text.vocabulary.* with mmap=None
# 2018-07-01 14:55:13,654 : INFO : loading trainables recursively from 300features_40minwords_10text.trainables.* with mmap=None
# 2018-07-01 14:55:13,655 : INFO : setting ignored attribute cum_table to None
# 2018-07-01 14:55:13,656 : INFO : loaded 300features_40minwords_10text
# /Users/jiwoonwon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# ...

# %%
df = pd.DataFrame(X_tsne, index=vocab[:100], columns=['x', 'y'])
df.shape
# Out:
# (100, 2)

# %%
df.head(10)
# Out:
#                x         y
# with    5.922052  3.336247
# all     4.832232 -2.446637
# this    2.188625 -4.189254
# stuff   3.481304 -3.091522
# go     -4.133384 -0.982258
# down    5.506244  5.384314
# at      7.492922  4.857608
# the     6.772376 -1.336147
# moment  4.735258 -4.540604
# mj     -2.816659  5.986703

# %%
fig = plt.figure()
fig.set_size_inches(40, 20)
ax = fig.add_subplot(1, 1, 1)

ax.scatter(df['x'], df['y'])

for word, pos in df.iterrows():
    ax.annotate(word, pos, fontsize=30)
    
plt.show()

# %% [markdown]
# ### 단어 벡터의 평균을 구함 & 랜덤포레스트

# %%
import numpy as np

def makeFeatureVecs(words, model, num_features):
    """
    주어진 문장에서 단어 벡터의 평균을 구하는 함수
    """
    # 속도를 빠르게 하기 위해 0으로 배열로 초기화
    featureVec = np.zeros((num_features,), dtype='float32')
    
    nwords = 0.
    # Index2Word: 모델의 사전에 있는 단어명을 담은 리스트
    index2word_set = set(model.wv.index2word)
    # loop를 돌며 모델 사전에 포함된 단어라면 feature에 추가
    for word in words:
        if word in index2word_set:
            nwords += 1
            featureVec = np.add(featureVec, model[word])
            
    # 결과를 단어 수로 나누어 평균을 구함
    featureVec = np.divide(featureVec, nwords)
    
    return featureVec

def getAvgFeatureVecs(reviews, model, num_features):
    """
    리뷰 단어 목록의 각각에 대한 평균 feature 벡터를 계산 & 2D 배열을 반환
    """
    counter = 0
    
    # 속도를 빠르게 하기 위해 배열 초기화
    reviewFeatureVecs = np.zeros((len(reviews), num_features), dtype='float32')
    
    for review in reviews:
        # 1000개 리뷰마다 상태출력
        if counter%1000. == 0.:
            print("Review %d of %d" % (counter, len(reviews)))
        # 평균 feature 벡터를 만들기 위해 위에서 정의한 함수를 호출
        reviewFeatureVecs[int(counter)] = makeFeatureVecs(review, model, num_features)
        counter += 1
        
    return reviewFeatureVecs

def getCleanReviews(reviews):
    """
    멀티스레드로 4개의 워커를 사용해 처리
    """
    clean_reviews = []
    clean_reviews = KaggleWord2VecUtility.apply_by_multiprocessing(\
                      reviews['review'], KaggleWord2VecUtility.review_to_wordlist,\
                      workers=4)
    return clean_reviews

# %%
# %time trainDataVecs = getAvgFeatureVecs(getCleanReviews(train), model, num_features)
# Out:
# Review 0 of 25000
# /Users/jiwoonwon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# Review 1000 of 25000
# Review 2000 of 25000
# Review 3000 of 25000
# Review 4000 of 25000
# Review 5000 of 25000
# Review 6000 of 25000
# Review 7000 of 25000
# Review 8000 of 25000
# Review 9000 of 25000
# Review 10000 of 25000
# Review 11000 of 25000
# Review 12000 of 25000
# Review 13000 of 25000
# Review 14000 of 25000
# Review 15000 of 25000
# Review 16000 of 25000
# Review 17000 of 25000
# Review 18000 of 25000
# Review 19000 of 25000
# Review 20000 of 25000
# Review 21000 of 25000
# Review 22000 of 25000
# Review 23000 of 25000
# Review 24000 of 25000
# CPU times: user 54.5 s, sys: 1.19 s, total: 55.7 s
# Wall time: 1min 17s

# %%
# %time testDataVecs = getAvgFeatureVecs(getCleanReviews(test), model, num_features)
# Out:
# Review 0 of 25000
# /Users/jiwoonwon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# Review 1000 of 25000
# Review 2000 of 25000
# Review 3000 of 25000
# Review 4000 of 25000
# Review 5000 of 25000
# Review 6000 of 25000
# Review 7000 of 25000
# Review 8000 of 25000
# Review 9000 of 25000
# Review 10000 of 25000
# Review 11000 of 25000
# Review 12000 of 25000
# Review 13000 of 25000
# Review 14000 of 25000
# Review 15000 of 25000
# Review 16000 of 25000
# Review 17000 of 25000
# Review 18000 of 25000
# Review 19000 of 25000
# Review 20000 of 25000
# Review 21000 of 25000
# Review 22000 of 25000
# Review 23000 of 25000
# Review 24000 of 25000
# CPU times: user 52.4 s, sys: 1.37 s, total: 53.8 s
# Wall time: 1min 17s

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=2018)

# %%
# %time forest = forest.fit(trainDataVecs, train['sentiment'])
# Out:
# CPU times: user 59.1 s, sys: 226 ms, total: 59.3 s
# Wall time: 8.17 s

# %%
from sklearn.model_selection import cross_val_score
# %time score = np.mean(cross_val_score(forest, trainDataVecs,\
                                      train['sentiment'], cv=10,\
                                      scoring='roc_auc'))
# Out:
# CPU times: user 8min 45s, sys: 2.66 s, total: 8min 48s
# Wall time: 1min 17s

# %%
score
# Out:
# 0.902006592

# %%
result = forest.predict(testDataVecs)

# %%
output = pd.DataFrame(data={'id': test['id'], 'sentiment': result})
output.to_csv('../data/imdb/Word2Vec_AverageVectors_{0:.5f}.csv'.format(score), index=False, quoting=3)

# %%
output_sentiment = output['sentiment'].value_counts()
print(output_sentiment[0] - output_sentiment[1])
output_sentiment
# Out:
# 190
# 0    12595
# 1    12405
# Name: sentiment, dtype: int64
